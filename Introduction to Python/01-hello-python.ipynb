# %% [markdown]
# # Python 1: Hello, Python
#
# **Your first lines of code.**
#
# *Author: The Genius Project Year 3*
#
# ---
#
# Python is a language for giving a computer instructions. You will use it to build match predictors later, but every expert started exactly here, with one line.
#
# **How to use this notebook:** click a grey code box and press **Shift + Enter** to run it.
# Read the note above each box first, then run it, then try changing something. You cannot
# break your computer by running Python. Mistakes are how you learn.

# %% [markdown]
# ### Printing
#
# `print()` shows a message on the screen. The text goes inside quotes.

# %%
print("Hello, Python")
# Out:
# Hello, Python

# %% [markdown]
# Run the box above. You should see the words appear underneath it. Now change the words inside the quotes to your own name and run it again.

# %%
print("My name is ...")
# Out:
# My name is ...

# %% [markdown]
# ### You can print more than once
#
# Each `print` starts a new line.

# %%
print("The Genius Project")
print("Year 3")
print("Let's predict some football")
# Out:
# The Genius Project
# Year 3
# Let's predict some football

# %% [markdown]
# ### Comments
#
# A line that starts with `#` is a note for humans. Python ignores it. Comments explain what your code does.

# %%
# This line is a note and does nothing.
print("Only this line runs")   # notes can also sit after code
# Out:
# Only this line runs

# %% [markdown]
# ### Your turn
#
# 1. Print your favourite football team.
# 2. Print three lines: your name, your age, and your favourite team.
# 3. Add a comment above each line saying what it does.
#
# When you are ready, open **Python 2: Numbers and Variables**.
